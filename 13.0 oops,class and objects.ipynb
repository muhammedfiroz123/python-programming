# %% [markdown]
# ## CLASS AND OBJECTS

# %%
#python class
class my_class:
    x=5

# %%
#creating a object p1
p1=my_class()
print(p1.x)
# Out:
# 5

# %%
## self is keyword
class dog:
  def __init__(self,name,age):
    self.name=name
    self.age=age

dog1=dog('buddy',4)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# buddy
# 4

# %%
dog2=dog('licky',3)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# ...
# licky
# 3

# %%
# define a class with instance methond
class dog:
  def __init__(self,name,age):
    self.name=name
    self.age=age


  def bark(self):
    print(f"{self.name}  says woof")

dog1=dog('buddy',3)
dog1.bark()
dog2=dog('licky',4)
dog2.bark()
# Out:
# buddy  says woof
# licky  says woof

# %%
class Bankaccount:
  def __init__(self,owner,balance=0):
    self.owner=owner
    self.balance=balance
  
  def deposite(self,amount):
    self.balance+=amount
    print(f'{amount} is creadit your account.new balance is {self.balance}')

  def withdraw(self,amount):
    if amount>self.balance:
      print('Insuficient balance')
    else:
      self.balance-= amount
      print(f'{amount} is withdraw .  new balance {self.balance}')

  def get_balance(self):
    print( self.balance)



## creatin a account
account=Bankaccount('firoz',234567)
print(account.owner)
print(account.balance)
# Out:
# firoz
# 234567

# %%
account.deposite(34562)
# Out:
# 34562 is creadit your account.new balance is 269129

# %%
account.withdraw(10023)
# Out:
# 10023 is withdraw .  new balance 259106

# %%
account.get_balance()
# Out:
# 259106

# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
p1=person("john",34)
print(p1.name)
print(p1.age)
# Out:
# john
# 34

# %% [markdown]
# All classes have a function called init(), which is always executed when the class is being initiated.
# Use the init() function to assign values to object properties, or other operations that are necessary to do when the object is being created:
# The init method is the Python equivalent of the C++ constructor in an object-oriented approach.
# The init function is called every time an object is created from a class.
# The init method lets the class initialize the object's attributes and serves no other purpose.
# It is only used within classes.
