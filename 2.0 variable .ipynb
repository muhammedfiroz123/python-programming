# %% [markdown]
# ## variables

# %%
a=100
a
# Out:
# 100

# %%
## declaring and assigning variables
age=23
height=5.8
name='MUHAMMED FIROZ'
IS_student=True

## printing the variables
print('age:',age)
print('height:',height)
print('name:',name)
# Out:
# age: 23
# height: 5.8
# name: MUHAMMED FIROZ

# %%
## naming coventions
# variables names should be descriptive
## they must start with letter or an _ ,and contains letter,number and uderscores
## variables names case sensitive

#valid variables names
first_name='muhammed'
second_name='firoz'

# %%
## naming coventions
# variables names should be descriptive
## they must start with letter or an _ ,and contains letter,number and uderscores
## variables names case sensitive

#valid variables names
first_name='muhammed'
second_name='firoz'

# %%
#invalid variable name 
2 names="frioz and faisal"
# Out:
#   Cell In[7], line 2
#     2 names="frioz and faisal"
#       ^
# SyntaxError: invalid syntax

# %%
age=30 # intiger
height=5.8 # flot
name='firoz' # string
is_student=True # boolean

print(type(is_student))
# Out:
# <class 'bool'>

# %%
# type coverting
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# 30
# <class 'str'>

# %%
age='23'
print(type(age))
z=int(age)
print(z)
print(type(z))
# Out:
# <class 'str'>
# 23
# <class 'int'>

# %%
height=5.7
type(height)
# Out:
# float

# %%
print(int(height))
print(float(int(height)))
# Out:
# 5
# 5.0

# %%
var=10
print(var,type(var))
var1=11.1
print(var1,type(var1))
# Out:
# 10 <class 'int'>
# 11.1 <class 'float'>

# %%
## input
age=input('the age is')
print(age,type(age))
# Out:
# 23 <class 'str'>

# %%
age=int(input('THE AGE IS:'))
print('AGE:',age,type(age))
# Out:
# AGE: 23 <class 'int'>

# %%
# making simple calculator

num1=float(input('enter first number'))
num2=float(input('enter second number'))

sum=num1+num2
difference=num1-num2
product=num1*num2
qoutient=num1/num2

print('Sum',sum)
print('difference',difference)
print('product',product)
print('qoutient',qoutient)
# Out:
# Sum 58.0
# difference 34.0
# product 552.0
# qoutient 3.8333333333333335
