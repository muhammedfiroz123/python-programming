# %% [markdown]
# ## condition statements

# %%
## if state ment
age= 20
if age>=18:
  print('you are allowed  to vote in election')
# Out:
# you are allowed  to vote in election

# %%
## else
age=16
if age>=18:
  print('you aare eligible to veting')
else:
  print('you are minor')
# Out:
# you are minor

# %%
## elif
age=17
if age <13:
  print('you are a child')
elif age<=18:
  print('you are a teenager')
else:
  print('you are a adult')
# Out:
# you are a teenager

# %%
## nested conditional statement
# num,odd,even,negative
num=int(input('enter a number'))
print(num)
if num >0:
  print('The number is positive')
  if num%2==0:
    print('The number is even')
  else:
    print('number is odd')
else:
  print('number is negative')
# Out:
# 9
# The number is positive
# number is odd

# %%
## Use cases
## determine if a year is a leap year 
year= int(input('enter the year'))
if year%4==0:
  if year%100==0:
    if year%400==0:
      print(year ,' is a leap year')
    else:
      print(year,'is not a leap year')
  else:
    print(year, 'is a leap year')
else:
  print(year ,'is not a leap year')
# Out:
# 2023 is not a leap year

# %%
# making simple calculator

num1=float(input('Enter first number '))
num2=float(input('Enter second number'))
operation=input('enter the operation(+,-,*,/):')

if operation=='+':
  result=num1+num2
elif operation=='-':
  result=num1-num2
elif operation=='*':
  result=num1*num2
elif operation=='/':
  if num2!=0:
    result=num1/num2
  else:
    result='error its not devisible'
else:
  result='syntax error'

print('RESULT=',result)
# Out:
# RESULT= 30.0

# %%
###  ticket price 

age=int(input('enter your age:'))
is_student=input('Enter is a student ? (yes/no):')

if age <5:
  price='FREE'
elif age<=12:
  price='$10'
elif age<=17:
  if is_student=='yes':
    price='$12'
  else:
    price='$18'
elif age<=40:
  if is_student=='yes':
    price='$25'
  else:
    price='$30'
else:
  price='$35'    


print('Ticket price:',price)
# Out:
# Ticket price: $30
