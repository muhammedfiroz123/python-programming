# %% [markdown]
# ## Data Types

# %%
## integer examples
age=23
type(age)
# Out:
# int

# %%
## floating piont datatype
height=5.7
print(height)
print(type(height))
# Out:
# 5.7
# <class 'float'>

# %%
#string datatypes
name='firoz'
print(name)
print(type(name))
# Out:
# firoz
# <class 'str'>

# %%
## boolean data type
he_is_a_student=True
print(he_is_a_student)
print(type(he_is_a_student))
# Out:
# True
# <class 'bool'>

# %%
a=10
b=10
type(a==b)
# Out:
# bool

# %%
## comman error
result='hello'+5
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ## comman error
# ----> 2 result='hello'+5
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
## solve this
result='hello'+str(5)
print(result)
# Out:
# hello5
