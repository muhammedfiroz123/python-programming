# %%
dict1={
    "brand":"honda",
    "model":"swift",
    "year" :2023
}
dict1
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': 2023}

# %%
dict2={
    "brand":"honda",
    "model":"swift",
    "year" :[2023,2030,2019]
}
dict2
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': [2023, 2030, 2019]}

# %%
dict2["brand"]
# Out:
# 'honda'

# %%
dict5={
    "brand":"milma",
    "model":"23/2023",
    "year" :{2023,2030,2019,2022,2028}
}
dict5
# Out:
# {'brand': 'milma', 'model': '23/2023', 'year': {2019, 2022, 2023, 2028, 2030}}

# %%
print(type(dict2))
# Out:
# <class 'dict'>

# %%
dict2={
    "brand":"honda",
    "model":"swift",
    "year" :[2023,2030,2019]
}
x=dict2.keys()
x
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
print(len(dict2))
# Out:
# 3

# %%
dict2.values()
# Out:
# dict_values(['honda', 'swift', [2023, 2030, 2019]])

# %%
dict_p={
    "brand":"honda",
    "model":"swift",
    "year" :[2023,2030,2019]
}

print(dict_p)
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': [2023, 2030, 2019]}

# %%
dict_p.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
dict_p["colour"]:"red"

# %%
print(dict_p)
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': [2023, 2030, 2019]}

# %%
## dictionary are mutable its update ,pop, del,clear,add 
print(dict_p.keys())
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
dict_p.update({"clour":"red"})
print(dict_p)
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': [2023, 2030, 2019], 'clour': 'red'}

# %%
dict_p.popitem()
# Out:
# ('clour', 'red')

# %%
dict_p.pop("brand")
# Out:
# 'honda'

# %%
#del dict_p
#dict_p

# %%
dict_p={
    "brand":"honda",
    "model":"swift",
    "year" :[2023,2030,2019]
}

print(dict_p)
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': [2023, 2030, 2019]}

# %%
dict_p.items()
# Out:
# dict_items([('brand', 'honda'), ('model', 'swift'), ('year', [2023, 2030, 2019])])

# %%
dict_p.get("brand")
# Out:
# 'honda'

# %%
dict_p={
    "brand":"honda",
    "model":"swift",
    "year" :[2023,2030,2019]
}

print(dict_p)
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': [2023, 2030, 2019]}

# %%
dict_p==dict1
# Out:
# False

# %%
dict_p==dict2
# Out:
# True

# %%
dt1=dict(name='manu',age='18')
print(dt1)
# Out:
# {'name': 'manu', 'age': '18'}

# %%
s={}
s["name"]="manu"
s["age"]=18
s
# Out:
# {'name': 'manu', 'age': 18}

# %%
grade={"rajan":"A+","sugu":" A","manu":" B+","abdu":"A+"}
print("NAME GRADES")
for i in grade:
    print(i,grade[i])
# Out:
# NAME GRADES
# rajan A+
# sugu  A
# manu  B+
# abdu A+

# %%
grade={"rajan":"A+","sugu":" A","manu":" B+","abdu":"A+"}
for keys,value in grade.items():
  print(f"{keys}:{value}")
# Out:
# rajan:A+
# sugu: A
# manu: B+
# abdu:A+

# %%
## Nested dictionary
student={
  'student1':{'name':'firoz','age':'23'},
  'student2':{'name':'hashim','age':'22'}

}

print(student)
# Out:
# {'student1': {'name': 'firoz', 'age': '23'}, 'student2': {'name': 'hashim', 'age': '22'}}

# %%
## accesing nested dictionary
print(student['student1']['age'])
print(student['student2']['name'])
# Out:
# 23
# hashim

# %%
price={
    "A":3,
    "B":6,
    "C":4
}
print(price)
quantity={
    "A":2,
    "B":4,
    "C":5
}
print(quantity)

money_spend=0
for i in price:
          money_spend=money_spend+(price[i]*quantity[i])
print(money_spend)
# Out:
# {'A': 3, 'B': 6, 'C': 4}
# {'A': 2, 'B': 4, 'C': 5}
# 50

# %%
for x in dict_p.values():
    print(x)
# Out:
# honda
# swift
# [2023, 2030, 2019]

# %%
for x in dict_p.items():
    print(x)
# Out:
# ('brand', 'honda')
# ('model', 'swift')
# ('year', [2023, 2030, 2019])

# %%
for x in dict_p.keys():
    print(x)
# Out:
# brand
# model
# year

# %%
for x,y in dict_p.items():
    print(x,y)
# Out:
# brand honda
# model swift
# year [2023, 2030, 2019]

# %%
z=dict_p.copy()
print(z)
# Out:
# {'brand': 'honda', 'model': 'swift', 'year': [2023, 2030, 2019]}

# %%
my_family={
    "child1":{
        "name":"sabu",
        "age":20,
        "dob":2003
        
    },
    "child2":{
        "name":"rahul",
        "age":23,
        "dob":1999
    },
    "child3":{
        "name":"raju",
        "age":23,
        "dob":2000
    },
}

print(my_family)
# Out:
# {'child1': {'name': 'sabu', 'age': 20, 'dob': 2003}, 'child2': {'name': 'rahul', 'age': 23, 'dob': 1999}, 'child3': {'name': 'raju', 'age': 23, 'dob': 2000}}

# %%
print(my_family["child1"]["name"])
# Out:
# sabu

# %%
print(my_family["child3"]["dob"])
# Out:
# 2000

# %%
## Dictionary comphrension

sqaure={x:x**2 for x in range(5)}
print(sqaure)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
even={ x :x**2  for x in range(1,20) if x%2==0}
print(even)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100, 12: 144, 14: 196, 16: 256, 18: 324}

# %%
odd={ x :x**3  for x in range(1,20) if x%2==1}
print(odd)
# Out:
# {1: 1, 3: 27, 5: 125, 7: 343, 9: 729, 11: 1331, 13: 2197, 15: 3375, 17: 4913, 19: 6859}

# %%
19**3
# Out:
# 6859

# %%
numbers=[1,2,3,3,4,5,6,4,5,7,8,7,5,9,7,3]
frequency={}
for number in numbers:
  if number in frequency:
    frequency[number]+=1
  else:
    frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 1, 3: 3, 4: 2, 5: 3, 6: 1, 7: 3, 8: 1, 9: 1}
