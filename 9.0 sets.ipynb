# %%
set1={2,3,4,"hello","banana",True}
print(set1)
# Out:
# {True, 2, 3, 4, 'banana', 'hello'}

# %%
set1={2,3,4,"hello","banana",True}
print(len(set1))
# Out:
# 6

# %%
set1={1,3,4,"hello","banana",True}
print(set1)
print(len(set1))
# Out:
# {1, 3, 4, 'banana', 'hello'}
# 5

# %%
set1={1,3,4,"hello","banana",True}
print(type(set1))
# Out:
# <class 'set'>

# %%
set1={1,3,4,"hello","banana",True}
for n in set1:
    print(n)
# Out:
# 1
# 3
# 4
# banana
# hello

# %%
set1={1,3,4,"hello","banana",True}
print('hello'in set1)
# Out:
# True

# %%
5 in set1
# Out:
# False

# %%
6 not in set1
# Out:
# True

# %%
#difference
x={"car","bus",'bike'}
y={"jeep","swift","car"}
z=x.difference(y)
print(z)
print(x-y)
# Out:
# {'bike', 'bus'}
# {'bike', 'bus'}

# %%
print(x)
# Out:
# {'bike', 'car', 'bus'}

# %%
s1={'banana','mango',"kiwi","orange"}
s2={"car",'bike','mango','bus'}
x=s1.symmetric_difference(s2)
print(s1^s2)
print(x)
# Out:
# {'orange', 'banana', 'car', 'bus', 'bike', 'kiwi'}
# {'orange', 'banana', 'car', 'bus', 'bike', 'kiwi'}

# %%
s1={'banana','mango',"kiwi","orange"}
s1.discard("banana")
print(s1)
# Out:
# {'orange', 'kiwi', 'mango'}

# %%
s1={'banana','mango',"kiwi","orange"}
s1.pop()
print(s1)
# Out:
# {'kiwi', 'mango', 'banana'}

# %%
s1={'banana','mango',"kiwi","orange"}
s2={"car",'bike','mango','bus'}
x=s1.update(s2)
print(x)
# Out:
# None

# %%
a={"car",'bike','mango','bus'}
b={'car','me','1'}

# %%
s2={"car",'bike','mango','bus'}
s2.clear()
print(s2)
# Out:
# set()

# %%
s2={"car",'bike','mango','bus'}
del s2
print(s2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 s2={"car",'bike','mango','bus'}
#       2 del s2
# ----> 3 print(s2)
#
# NameError: name 's2' is not defined

# %%
s2={"car",'bike','mango','bus'}
s2.add('train')
print(s2)
# Out:
# {'mango', 'train', 'car', 'bus', 'bike'}

# %%
x={2,3,6,8,9}
y={1,8,8,4,3}
x=x.union(y)
print(x)
# Out:
# {1, 2, 3, 4, 6, 8, 9}

# %%
x={2,3,6,8,9}
y={1,8,8,4,3}
c={3,5,6,78,9}
z=x.union(y,c)
print(x|y)
print(z)
# Out:
# {1, 2, 3, 4, 6, 8, 9}
# {1, 2, 3, 4, 5, 6, 8, 9, 78}

# %%
s1={1,2,3,4,5,6,7}
s2={2,3,4,5}
z=s1.issubset(s2)
print(z)
# Out:
# False

# %%
s1={1,2,3,4,5,6,7}
s2={2,3,4,5}
z=s2.issubset(s1)
print(z)
# Out:
# True

# %%
s1={1,2,3,4,5,6,7}
s2={2,3,4,5}
z=s1.issuperset(s2)
print(z)
# Out:
# True

# %%
s1={1,2,3,4,5,6,7}
s2={2,3,4,5}
z=s1.intersection(s2)
print(z)
# Out:
# {2, 3, 4, 5}

# %%
s1={1,2,3,4,5,6,7}
s2={2,3,4,5}
print(s1&s2)
# Out:
# {2, 3, 4, 5}

# %%
x={"hai","mango","kiwi","orange"}
x.remove("hai")
print(x)
# Out:
# {'kiwi', 'orange', 'mango'}

# %%
text ='in this tutorial are discuss about the sets'
words= text.split()
unique_words=set(words)
print(unique_words)
print(len(unique_words))
# Out:
# {'are', 'about', 'tutorial', 'discuss', 'this', 'sets', 'the', 'in'}
# 8
