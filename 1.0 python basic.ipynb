# %% [markdown]
# ## python basics

# %% [markdown]
# ### syntax

# %%
## multy line command  is use ''' use this up and down
"""""""firoz is a good boy"""""""
"""he is a stuady well """
# Out:
# 'he is a stuady well '

# %%
## case senscitive in python
name="muhammed"
Name="firoz"
print(name)
print(Name)
# Out:
# muhammed
# firoz

# %%
name="muhammed"
Name="firoz"
print(name+Name)
# Out:
# muhammedfiroz

# %%
## indentation
age=32
if age>33:
  print(age)
else:
  print('age not found')

# the space using between the two codes is automaticaly consider
# Out:
# age not found

# %%
## line continuation
## using \ using 
total= 1+2+3+4+5+6+7+\
4+5+6
print(total)
# Out:
# 43

# %%
## multiple statement on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## understand semnatics in python 
# variable assignment
age=32 # age is a integer
name= 'firoz'# name is string

# %%
# type inference
print('name is :',type(name))
print('age is :',type(age))
# Out:
# name is : <class 'str'>
# age is : <class 'int'>

# %%
## name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ## name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## code example of indentation
if True:
  print('correct indentation')
  if False:
    print('this is not print')
  print('this will print')
print('outside the if block')
# Out:
# correct indentation
# this will print
# outside the if block
